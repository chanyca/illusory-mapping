# %%
# conda create --name bcitoolbox python=3.10

from bcitoolbox_local import simulateVV
import numpy as np
import matplotlib.pyplot as plt
from collections import defaultdict
from helpers import get_best_models, get_subject_ids

plot_indiv = False
location = 'invisible'

# %%
strategy_map = {
    'Averaging': 'ave',
    'Selection': 'sel',
    'Matching': 'mat',
}

def simulate_data(parameters, strategy_name, fitType, file_name,
                  modeling_data_path='csv/modeling/data/',
                  n_simulation=10000, biOnly=0):
    
    data_file_path = modeling_data_path + file_name
    behavior_data = np.loadtxt(data_file_path, delimiter=',')
    if len(behavior_data) < 10: return

    strategy = strategy_map.get(strategy_name[0])

    error, modelprop, dataprop, responsesSim, r2 = simulateVV(parameters, 
                                                              n_simulation, 
                                                              behavior_data, 
                                                              biOnly,
                                                              strategy, 
                                                              fitType,)

    return error, modelprop, dataprop, responsesSim, r2

# %%
# Simulate data for each subject
condition_map = None
best_models_df = get_best_models('bci', sigma_a=0.2)
# best_models_df = find_best_model_per_subject()
all_props = defaultdict(dict)

for location in [location]: 
    location_df = best_models_df[best_models_df['location'] == location]

    for index, row in location_df.iterrows():
        subject = row['subject_id']
        file_name = f"{subject}_{location}.csv"
        Strategies = [row['strategy']]
        FitType = row['fit_type']
        model = 'bci'

        if condition_map is None:
            behavior_data = np.loadtxt(f'csv/modeling/data/{file_name}', delimiter=',')
            stimuli = behavior_data[:, [0, 1]]
            condition_map = np.unique(stimuli, axis=0)
            print("condition_map.shape:", condition_map.shape)

        print("\n=======================================")
        print(f"Simulating data for {subject} at {location}")
        print("=======================================\n")

        parameters = [
            row['pcommon'],
            row['sigma_v'],
            row['sigma_a'],
            row['mu_p'],
            row['sigma_p'],            
        ]
        results = simulate_data(parameters, Strategies, FitType, file_name)

        if results is not None:
            error, modelprop, dataprop, responsesSim, r2 = results
            # store simulated data
            all_props[subject][location] = {
                'modelprop': modelprop,
                'dataprop': dataprop,
                'r2': r2
            }

            # Split modelprop and dataprop according to conditions
            for i, condition in enumerate(condition_map):
                all_props[subject][location][f'F{int(condition[0])}B{int(condition[1])}'] = {
                    'model': model,
                    'Visual model': modelprop[0, i, :],
                    'Visual response': dataprop[0, i, :],
                }
# Out:
# condition_map.shape: (4, 2)
#
# =======================================
# Simulating data for LV001 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.1208798691176651 =====
# ===== DEBUG: sigma_v = 0.4412213420338129 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.812701089794534 =====
# R2 on all
# 0.37455397262117845
# Sum Loglike    Optimal
# -1108.4475532003512 -228.87982208797575
# Explainable variance, r2:
# -0.02403555731764495
#
# =======================================
# Simulating data for LV002 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9999863547816554 =====
# ===== DEBUG: sigma_v = 0.7418661785768073 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 2.9999399541665674 =====
# R2 on all
# 0.6512268406773907
# Sum Loglike    Optimal
# -1059.9095045351332 -220.12779541730015
# Explainable variance, r2:
# 0.5194963257595019
#
# =======================================
# Simulating data for LV003 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.973038599854972 =====
# ===== DEBUG: sigma_v = 0.6145849201791227 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.623177323751303 =====
# R2 on all
# 0.4567345052033522
# Sum Loglike    Optimal
# -498.4975331390805 -82.71942458030654
# Explainable variance, r2:
# 0.20726545499841753
#
# =======================================
# Simulating data for LV005 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9836638976892124 =====
# ===== DEBUG: sigma_v = 0.4103406239176207 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.1333172421988196 =====
# R2 on all
# 0.583396507747512
# Sum Loglike    Optimal
# -582.9332653805689 -138.9353801781409
# Explainable variance, r2:
# 0.360755818958423
#
# =======================================
# Simulating data for LV008 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.1917540334608184 =====
# ===== DEBUG: sigma_v = 0.1325811295078546 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.6331705044815008 =====
# R2 on all
# 0.46345018038609587
# Sum Loglike    Optimal
# -1330.0571176216536 -215.1306480420393
# Explainable variance, r2:
# 0.1811469219165054
#
# =======================================
# Simulating data for LV009 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.4991750080159247 =====
# ===== DEBUG: sigma_v = 0.2266705470624264 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.8546382229334208 =====
# R2 on all
# 0.5740331443914927
# Sum Loglike    Optimal
# -566.7148973491247 -111.33393626689269
# Explainable variance, r2:
# 0.3895377847640843
#
# =======================================
# Simulating data for LV011 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.2357899611393558 =====
# ===== DEBUG: sigma_v = 2.998424813663723 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 2.9995186048515063 =====
# R2 on all
# 0.44723947538990155
# Sum Loglike    Optimal
# -991.0335662426864 -214.00415729390903
# Explainable variance, r2:
# 0.04720596571422009
#
# =======================================
# Simulating data for LV012 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9802466960583625 =====
# ===== DEBUG: sigma_v = 0.5103325730509499 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.7137148820958048 =====
# R2 on all
# 0.5537366606215485
# Sum Loglike    Optimal
# -1604.9609994585062 -331.937034972626
# Explainable variance, r2:
# 0.3438954548954962
#
# =======================================
# Simulating data for LV013 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.8879892856504997 =====
# ===== DEBUG: sigma_v = 0.3306740604107102 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.7842845507719789 =====
# R2 on all
# 0.5745199109875466
# Sum Loglike    Optimal
# -1427.3471075995199 -328.98932917466345
# Explainable variance, r2:
# 0.39815697627933233
#
# =======================================
# Simulating data for LV015 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.0124428319066942 =====
# ===== DEBUG: sigma_v = 0.1177967590056548 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.203263696197596 =====
# R2 on all
# 0.691627089926592
# Sum Loglike    Optimal
# -36.31080527388988 -4.144053874185416
# Explainable variance, r2:
# 0.6400050240627628
#
# =======================================
# Simulating data for LV016 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.2013361941976145 =====
# ===== DEBUG: sigma_v = 0.1272702401123678 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.517129291462837 =====
# R2 on all
# 0.5364036455369069
# Sum Loglike    Optimal
# -1382.6866824145445 -250.6683880771813
# Explainable variance, r2:
# 0.2955819837830972
#
# =======================================
# Simulating data for LV019 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9999961935534104 =====
# ===== DEBUG: sigma_v = 0.6233107366769622 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 2.9999295825592025 =====
# R2 on all
# 0.1395836466051897
# Sum Loglike    Optimal
# -48.927296585162004 -3.701521026363638
# Explainable variance, r2:
# -0.3717034310126377
#
# =======================================
# Simulating data for LV021 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.0124428319054525 =====
# ===== DEBUG: sigma_v = 0.1177967590055255 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.2032636961981962 =====
# R2 on all
# 0.5242169134812705
# Sum Loglike    Optimal
# -277.67215584973974 -52.80132107895583
# Explainable variance, r2:
# 0.23327646613299813
#
# =======================================
# Simulating data for LV022 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.0854186943099562 =====
# ===== DEBUG: sigma_v = 0.1256313717762521 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 1.525177790924608 =====
# R2 on all
# 0.5486735212847863
# Sum Loglike    Optimal
# -807.9222149561778 -155.06384242167047
# Explainable variance, r2:
# 0.3079881527649322
#
# =======================================
# Simulating data for LV023 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.7454865495231714 =====
# ===== DEBUG: sigma_v = 2.7523582400410938 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.1186882846074306 =====
# R2 on all
# 0.4221943661628561
# Sum Loglike    Optimal
# -1326.718507285782 -300.5464351689726
# Explainable variance, r2:
# -0.05771753330862506
#
# =======================================
# Simulating data for LV024 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9184315571619104 =====
# ===== DEBUG: sigma_v = 0.3792576419874877 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.8437113667475072 =====
# R2 on all
# 0.48071755335189637
# Sum Loglike    Optimal
# -877.0103104529111 -198.39548714799514
# Explainable variance, r2:
# 0.1439314574517312
#
# =======================================
# Simulating data for LV025 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.0908194502076311 =====
# ===== DEBUG: sigma_v = 0.1292086658940105 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 2.055452520915848 =====
# R2 on all
# 0.5723195707228814
# Sum Loglike    Optimal
# -800.4349862400081 -144.78135043880707
# Explainable variance, r2:
# 0.3924063351754521
#
# =======================================
# Simulating data for SV103 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.3260619003343993 =====
# ===== DEBUG: sigma_v = 0.1270110353920731 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.5362426596799599 =====
# R2 on all
# 0.23276524596331322
# Sum Loglike    Optimal
# -31.282632606048068 -3.3952400015103557
# Explainable variance, r2:
# -0.2514479634662814
#
# =======================================
# Simulating data for SV111 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9997760246664288 =====
# ===== DEBUG: sigma_v = 2.5036128426928093 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 2.998500362604237 =====
# R2 on all
# 0.06278607501883797
# Sum Loglike    Optimal
# -47.81716185077548 -2.230536232274953
# Explainable variance, r2:
# -0.6681161723963069
#
# =======================================
# Simulating data for SV113 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.8258535450395093 =====
# ===== DEBUG: sigma_v = 0.3482914809098672 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.5199564481394063 =====
# R2 on all
# 0.46724734625640924
# Sum Loglike    Optimal
# -63.838201037495 -10.027448206485008
# Explainable variance, r2:
# 0.25618894783070767
#
# =======================================
# Simulating data for SV119 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.91686345083164 =====
# ===== DEBUG: sigma_v = 0.3452664533100846 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 0.7437232657474243 =====
# R2 on all
# 0.7394994885233953
# Sum Loglike    Optimal
# -15.583510202070052 -3.35630277095148
# Explainable variance, r2:
# 0.7033382547099827
#
# =======================================
# Simulating data for SV215 at invisible
# =======================================
#
# fit type = mll
# ===== DEBUG: fixed values = [0.5, 0.4, 0.8, 4000, 2, 0, 0] =====
# ===== DEBUG: pcommon = 0.9997760246664288 =====
# ===== DEBUG: sigma_v = 2.5036128426913744 =====
# ===== DEBUG: sigma_a = 0.2 =====
# ===== DEBUG: sigma_p = 1.5 =====
# ===== DEBUG: mu_p = 2.9985003626042364 =====
# R2 on all
# 0.4345264965845638
# Sum Loglike    Optimal
# -23.45858300584919 -2.3548308959145112
# Explainable variance, r2:
# 0.2281739349857661

# %%
vis_col = '#6636a5'
resp_col = '#9b72cf'

subject_ids = get_subject_ids()

if plot_indiv:
    for subject_id in subject_ids:
        # start plotting
        fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(7, 2), sharey=True)
        flattened_axes = axes.flatten()
        ax=0

        for condition in ['F0B0', 'F1B0', 'F1B1', 'F1B2']:            
            flattened_axes[ax].plot(all_props[subject_id][location][condition]['Visual response'], resp_col, label='Visual response')
            flattened_axes[ax].plot(all_props[subject_id][location][condition]['Visual model'], vis_col, linestyle='--', label='Visual model')
            model = all_props[subject_id][location][condition]['model']

            # aesthetics
            flattened_axes[ax].set_ylabel('Probability') if condition=='F0B0' else flattened_axes[ax].set_ylabel('')
            flattened_axes[ax].set_title(f'{condition}')

            ax+=1

        plt.suptitle(f'{subject_id}', fontsize='15', fontweight='bold')
        fig.subplots_adjust(top=0.75, wspace=0.1)

        # legend
        handles, labels = flattened_axes[0].get_legend_handles_labels()
        fig.legend(handles, labels, loc='upper left', fontsize=9, ncol=2)

        # plt.show()

# %%
# Plot group average

vis_col = '#6636a5'
resp_col = '#9b72cf'

groups = ['Low Vision', 'Sighted Control']
conditions = ['F0B0', 'F1B0', 'F1B1', 'F1B2']

group_data = {
    'Low Vision': {cond: {'resp': [], 'mod': []} for cond in conditions},
    'Sighted Control': {cond: {'resp': [], 'mod': []} for cond in conditions}
}

for sid in all_props.keys():
    group = 'Low Vision' if sid.startswith('LV') else 'Sighted Control'
    for cond in conditions:
        if location in all_props[sid] and cond in all_props[sid][location]:
            group_data[group][cond]['resp'].append(all_props[sid][location][cond]['Visual response'])
            group_data[group][cond]['mod'].append(all_props[sid][location][cond]['Visual model'])

stats = {group: {cond: {} for cond in conditions} for group in groups}

for group in groups:
    for cond in conditions:
        resp_stack = np.array(group_data[group][cond]['resp'])
        mod_stack = np.array(group_data[group][cond]['mod'])
        
        # True data
        stats[group][cond]['resp_mean'] = np.mean(resp_stack, axis=0)
        stats[group][cond]['resp_sem'] = np.std(resp_stack, axis=0) / np.sqrt(len(resp_stack))
        
        # Model predictions
        stats[group][cond]['mod_mean'] = np.mean(mod_stack, axis=0)
        stats[group][cond]['mod_sem'] = np.std(mod_stack, axis=0) / np.sqrt(len(mod_stack))


fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(7, 4), sharex=True, sharey=True)

for row, group in enumerate(groups):
    for col, condition in enumerate(conditions):
        ax = axes[row, col]
        data = stats[group][condition]
        x = np.arange(len(data['resp_mean'])) # x-axis indices
        
        ax.plot(x, data['resp_mean'], color=resp_col, label='Visual response', lw=2)
        ax.fill_between(x, data['resp_mean'] - data['resp_sem'], 
                        data['resp_mean'] + data['resp_sem'], color=resp_col, alpha=0.3)
        
        ax.plot(x, data['mod_mean'], color=vis_col, linestyle='--', label='Visual model', lw=1.5)
        ax.set_ylim(-0.05, 1.05)
        if col == 0:
            ax.set_ylabel('Probability')
        if row == 0:
            ax.set_title(condition, fontweight='bold')

fig.text(0.02, 0.7, 'Low\nVision', va='center', ha='center', fontweight='bold')
fig.text(0.02, 0.3, 'Sighted\nControl', va='center', ha='center', fontweight='bold')
fig.text(0.5, 0.02, 'Reported Number of Flash(es)', ha='center')

# legend
handles, labels = axes[0, 0].get_legend_handles_labels()
fig.legend(handles, labels, loc='upper left', fontsize=9)

plt.tight_layout(rect=[0.05, 0.03, 1, 0.95])
plt.show()
